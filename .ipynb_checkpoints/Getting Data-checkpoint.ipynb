# %% [markdown]
# # This is the Notebook to get the Data from the CBS API

# %%
import pandas as pd
import cbsodata as cbs
import re
from glob import glob
import pyreadstat
import numpy as np
import os

# %%
# This function takes the unique categories of the identifier columns, puts their values in new columns and deletes the original column

def split_column(df, values, category, region, year):
    if type(values) is list:
        for x in df[f'{category}'].unique():
            for v in values:
                df[f'{x}_{v}'] = np.where(df[f'{category}'] == x, df[f'{v}'], None)
        for v in values:
            df = df.drop([f'{v}'], axis=1)
    if type(values) is str:
        for x in df[f'{category}'].unique():
            df[f'{x}_{values}'] = np.where(df[f'{category}'] == x, df[f'{values}'], None)
        df = df.drop([f'{values}'], axis=1)
    df = df.groupby([f'{region}', f'{year}']).agg(max).drop([f'{category}'], axis=1)
    return df

# %%
# This function takes the unique categories of the identifier columns, puts their values in new columns and deletes the original column

def split_column2(df, values, category1, category2, region, year):
    if type(values) is list:
        for x in df[f'{category1}'].unique():
            for y in df[f'{category2}'].unique():
                for v in values:
                    df[f'{x}_{y}_{v}'] = np.where((df[f'{category2}'] == y) & (df[f'{category1}'] == x), df[f'{v}'], None)
        for v in values:
            df = df.drop([f'{v}'], axis=1)
    if type(values) is str:
        for x in df[f'{category1}'].unique():
            for y in df[f'{category2}'].unique():
                df[f'{x}_{y}_{values}'] = np.where((df[f'{category2}'] == y) & (df[f'{category1}'] == x), df[f'{values}'], None)
        df = df.drop([f'{values}'], axis=1)
    df = df.groupby([f'{region}', f'{year}']).agg(max).drop([f'{category1}', f'{category2}'], axis=1)
    return df

# %% [markdown]
# ## Downloading Population number

# %%
metadata = pd.DataFrame(cbs.get_meta('37259ned', 'DataProperties'))
metadata
# Out:
#                  odata.type  ID  Position  ParentID           Type  \
# 0       Cbs.OData.Dimension   0       0.0       NaN      Dimension
# 1    Cbs.OData.GeoDimension   1       1.0       NaN   GeoDimension
# 2   Cbs.OData.TimeDimension   2       2.0       NaN  TimeDimension
# 3           Cbs.OData.Topic   3       3.0       NaN          Topic
# 4           Cbs.OData.Topic   4       4.0       NaN          Topic
# 5      Cbs.OData.TopicGroup   5       NaN       NaN     TopicGroup
# 6           Cbs.OData.Topic   6       5.0       5.0          Topic
# 7           Cbs.OData.Topic   7       6.0       5.0          Topic
# 8      Cbs.OData.TopicGroup   8       NaN       NaN     TopicGroup
# 9           Cbs.OData.Topic   9       7.0       8.0          Topic
# 10          Cbs.OData.Topic  10       8.0       8.0          Topic
# 11          Cbs.OData.Topic  11       9.0       NaN          Topic
# 12     Cbs.OData.TopicGroup  12       NaN       NaN     TopicGroup
# 13          Cbs.OData.Topic  13      10.0      12.0          Topic
# 14          Cbs.OData.Topic  14      11.0      12.0          Topic
# 15          Cbs.OData.Topic  15      12.0      12.0          Topic
# 16          Cbs.OData.Topic  16      13.0      12.0          Topic
# 17     Cbs.OData.TopicGroup  17       NaN       NaN     TopicGroup
# 18          Cbs.OData.Topic  18      14.0      17.0          Topic
# 19          Cbs.OData.Topic  19      15.0      17.0          Topic
# 20          Cbs.OData.Topic  20      16.0      17.0          Topic
# 21          Cbs.OData.Topic  21      17.0      17.0          Topic
# 22          Cbs.OData.Topic  22      18.0      17.0          Topic
# 23          Cbs.OData.Topic  23      19.0       NaN          Topic
# 24     Cbs.OData.TopicGroup  24       NaN       NaN     TopicGroup
# 25          Cbs.OData.Topic  25      20.0      24.0          Topic
# 26          Cbs.OData.Topic  26      21.0      24.0          Topic
# 27          Cbs.OData.Topic  27      22.0       NaN          Topic
#
#                                           Key  \
# 0                                    Geslacht
# 1                                      RegioS
# 2                                    Perioden
# 3                       BevolkingOp1Januari_1
# 4                       Bevolkingsdichtheid_2
# 5
# 6                     LevendGeborenKinderen_3
# 7             LevendGeborenKinderenRelatief_4
# 8
# 9                               Overledenen_5
# 10                      OverledenenRelatief_6
# 11                        Geboorteoverschot_7
# 12
# 13                          TotaalVestiging_8
# 14                  TotaalVestigingRelatief_9
# 15                              Immigratie_10
# 16                       UitAndereGemeente_11
# 17
# 18        TotaalVertrekInclusiefCorrecties_12
# 19        TotaalVertrekInclusiefCoRelatief_13
# 20      EmigratieInclusiefAdministratieveC_14
# 21          SaldoAdministratieveCorrecties_15
# 22                      NaarAndereGemeente_16
# 23  VestigingsoverschotInclusiefCorrecties_17
# 24
# 25                             TotaleGroei_18
# 26                     TotaleGroeiRelatief_19
# 27                   BevolkingOp31December_20
#
#                                        Title  \
# 0                                   Geslacht
# 1                                    Regio's
# 2                                   Perioden
# 3                     Bevolking op 1 januari
# 4                        Bevolkingsdichtheid
# 5                    Levend geboren kinderen
# 6                    Levend geboren kinderen
# 7          Levend geboren kinderen, relatief
# 8                                Overledenen
# 9                                Overledenen
# 10                     Overledenen, relatief
# 11                         Geboorteoverschot
# 12                  Vestiging in de gemeente
# 13                          Totaal vestiging
# 14                Totaal vestiging, relatief
# 15                                Immigratie
# 16                       Uit andere gemeente
# 17                   Vertrek uit de gemeente
# 18       Totaal vertrek inclusief correcties
# 19  Totaal vertrek inclusief co..., relatief
# 20  Emigratie inclusief administratieve c...
# 21          Saldo administratieve correcties
# 22                      Naar andere gemeente
# 23  Vestigingsoverschot inclusief correcties
# 24                           Bevolkingsgroei
# 25                              Totale groei
# 26                    Totale groei, relatief
# 27                  Bevolking op 31 december
#
#                                           Description  MapYear ReleasePolicy  \
# 0                                                None      NaN           NaN
# 1                                                None      NaN           NaN
# 2                                                          NaN          True
# 3   Bevolking:\r\nDe inwoners van een bepaald gebi...      NaN           NaN
# 4   Bevolking op 1 januari per km2 oppervlakte lan...      NaN           NaN
# 5   Levend geboren kind:\r\nKind dat na geboorte e...      NaN           NaN
# 6                                                None      NaN           NaN
# 7   Levend geboren kinderen per duizend van de gem...      NaN           NaN
# 8   Overledene:\r\nPersoon die is overleden waarbi...      NaN           NaN
# 9                                                None      NaN           NaN
# 10  Overledenen per duizend van de gemiddelde bevo...      NaN           NaN
# 11  Het aantal levend geboren kinderen min het aan...      NaN           NaN
# 12  Personen die in een gemeente komen wonen na ve...      NaN           NaN
# 13  Totaal in de gemeente gevestigde personen.\r\n...      NaN           NaN
# 14  Totaal in de gemeente gevestigde personen per ...      NaN           NaN
# 15  Vestiging van personen vanuit het buitenland i...      NaN           NaN
# 16  Personen die verhuizen waarbij het oude adres ...      NaN           NaN
# 17  Personen die verhuizen naar een andere gemeent...      NaN           NaN
# 18  Totaal uit de gemeente vertrokken personen inc...      NaN           NaN
# 19  Totaal uit de gemeente vertrokken personen inc...      NaN           NaN
# 20  Emigratie inclusief het saldo van de administr...      NaN           NaN
# 21  Tot 1977 heeft het CBS geen informatie over ad...      NaN           NaN
# 22  Personen die verhuizen waarbij het nieuwe adre...      NaN           NaN
# 23  Vestigingsoverschot inclusief het saldo van de...      NaN           NaN
# 24  De toe- of afname van de bevolking.\r\nInclusi...      NaN           NaN
# 25                                               None      NaN           NaN
# 26  Bevolkingsgroei per duizend van de bevolking o...      NaN           NaN
# 27  Bevolking:\r\nDe inwoners van een bepaald gebi...      NaN           NaN
#
#    Datatype      Unit  Decimals     Default PresentationType
# 0       NaN       NaN       NaN         NaN              NaN
# 1       NaN       NaN       NaN         NaN              NaN
# 2       NaN       NaN       NaN         NaN              NaN
# 3      Long    aantal       0.0  Impossible         Absolute
# 4      Long    aantal       0.0  Impossible         Relative
# 5       NaN       NaN       NaN         NaN              NaN
# 6      Long    aantal       0.0  Impossible         Absolute
# 7    Double  promille       1.0  Impossible         Relative
# 8       NaN       NaN       NaN         NaN              NaN
# 9      Long    aantal       0.0  Impossible         Absolute
# 10   Double  promille       1.0  Impossible         Relative
# 11     Long    aantal       0.0  Impossible         Absolute
# 12      NaN       NaN       NaN         NaN              NaN
# 13     Long    aantal       0.0  Impossible         Absolute
# 14   Double  promille       1.0  Impossible         Relative
# 15     Long    aantal       0.0  Impossible         Absolute
# 16     Long    aantal       0.0  Impossible         Absolute
# 17      NaN       NaN       NaN         NaN              NaN
# 18     Long    aantal       0.0  Impossible         Absolute
# 19   Double  promille       1.0  Impossible         Relative
# 20     Long    aantal       0.0  Impossible         Absolute
# 21     Long    aantal       0.0  Impossible         Absolute
# 22     Long    aantal       0.0  Impossible         Absolute
# 23     Long    aantal       0.0  Impossible         Absolute
# 24      NaN       NaN       NaN         NaN              NaN
# 25     Long    aantal       0.0  Impossible         Absolute
# 26   Double  promille       1.0  Impossible         Relative
# 27     Long    aantal       0.0  Impossible         Absolute

# %%
data = pd.DataFrame(cbs.get_data('37259ned', select = (['BevolkingOp1Januari_1', 'RegioS', 'Perioden', 'Geslacht'])))

# %%
val = 'BevolkingOp1Januari_1'
cat = 'Geslacht'
reg = 'RegioS'
year = 'Perioden'
data = split_column(data, val, cat, reg, year)

# %%
data.to_csv('Population.csv')

# %% [markdown]
# ## Downloading Fertility Data

# %%
metadata = pd.DataFrame(cbs.get_meta('37201', 'Perioden'))
metadata
# Out:
#          Key Title Description      Status
# 0   1988JJ00  1988        None  Definitief
# 1   1989JJ00  1989        None  Definitief
# 2   1990JJ00  1990        None  Definitief
# 3   1991JJ00  1991        None  Definitief
# 4   1992JJ00  1992        None  Definitief
# 5   1993JJ00  1993        None  Definitief
# 6   1994JJ00  1994        None  Definitief
# 7   1995JJ00  1995        None  Definitief
# 8   1996JJ00  1996        None  Definitief
# 9   1997JJ00  1997        None  Definitief
# 10  1998JJ00  1998        None  Definitief
# 11  1999JJ00  1999        None  Definitief
# 12  2000JJ00  2000        None  Definitief
# 13  2001JJ00  2001        None  Definitief
# 14  2002JJ00  2002        None  Definitief
# 15  2003JJ00  2003        None  Definitief
# 16  2004JJ00  2004        None  Definitief
# 17  2005JJ00  2005        None  Definitief
# 18  2006JJ00  2006        None  Definitief
# 19  2007JJ00  2007        None  Definitief
# 20  2008JJ00  2008        None  Definitief
# 21  2009JJ00  2009        None  Definitief
# 22  2010JJ00  2010        None  Definitief
# 23  2011JJ00  2011        None  Definitief
# 24  2012JJ00  2012        None  Definitief
# 25  2013JJ00  2013        None  Definitief
# 26  2014JJ00  2014        None  Definitief
# 27  2015JJ00  2015        None  Definitief
# 28  2016JJ00  2016        None  Definitief
# 29  2017JJ00  2017        None  Definitief
# 30  2018JJ00  2018        None  Definitief
# 31  2019JJ00  2019        None  Definitief
# 32  2020JJ00  2020        None  Definitief

# %%
data = pd.DataFrame(cbs.get_data('37201', select = (['LevendGeborenKinderenRelatief_2', 'RegioS', 'Perioden'])))

# %%
# Making RegioS and Perioden the index values as in other dataframes

data.index = pd.MultiIndex.from_arrays(data[['RegioS', 'Perioden']].values.T, names=['RegioS', 'Perioden'])
data = data.drop(['RegioS', 'Perioden'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-58a49064a260> in <module>
#       1 # Making RegioS and Perioden the index values as in other dataframes
#       2
# ----> 3 data.index = pd.MultiIndex.from_arrays(data[['RegioS', 'Perioden']].values.T, names=['RegioS', 'Perioden'])
#       4 data = data.drop(['RegioS', 'Perioden'], axis=1)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['RegioS', 'Perioden'], dtype='object')] are in the [columns]"

# %%
data.to_csv('Fertility.csv')

# %% [markdown]
# ## Downloading Unemployment Data

# %%
# Downloading data for unemployment
metadata = pd.DataFrame(cbs.get_meta('84961NED', 'Perioden'))
metadata
# Out:
#          Key Title Description CategoryGroupID
# 0   2003JJ00  2003                        None
# 1   2004JJ00  2004                        None
# 2   2005JJ00  2005                        None
# 3   2006JJ00  2006                        None
# 4   2007JJ00  2007                        None
# 5   2008JJ00  2008                        None
# 6   2009JJ00  2009                        None
# 7   2010JJ00  2010                        None
# 8   2011JJ00  2011                        None
# 9   2012JJ00  2012                        None
# 10  2013JJ00  2013                        None
# 11  2014JJ00  2014                        None
# 12  2015JJ00  2015                        None
# 13  2016JJ00  2016                        None
# 14  2017JJ00  2017                        None
# 15  2018JJ00  2018                        None
# 16  2019JJ00  2019                        None
# 17  2020JJ00  2020        None            None

# %%
data = pd.DataFrame(cbs.get_data('84961NED',
                                      select = ['Werkloosheidspercentage_13', 'RegioS',
                                                'Perioden', 'Persoonskenmerken']))
data = data[(data['Persoonskenmerken'] == 'Totaal personen') |
            (data['Persoonskenmerken'] == 'Geslacht: mannen') |
            (data['Persoonskenmerken'] == 'Geslacht: vrouwen')]

# %%
data['Geslacht: mannen_Werkloosheidspercentage_13'] = np.where(data['Persoonskenmerken'] == 'Geslacht: mannen', data['Werkloosheidspercentage_13'], None)
data = data.drop(['Werkloosheidspercentage_13'], axis=1)
data = data.groupby(['RegioS', 'Perioden']).agg(max).drop(['Persoonskenmerken'], axis=1)

# %%
val = 'Werkloosheidspercentage_13'
cat = 'Persoonskenmerken'
reg = 'RegioS'
year = 'Perioden'
data = split_column(data, val, cat, reg, year)

# %%
data.to_csv('Unemployment.csv')

# %% [markdown]
# ## Download immigration change data

# %% [markdown]
# alternatives:
#
# 84974NED - current, from 2011
#
# 60056ned - current, from 1988

# %%
metadata = pd.DataFrame(cbs.get_meta('60056ned', 'Perioden'))
metadata
# Out:
#          Key Title Description      Status
# 0   1988JJ00  1988        None  Definitief
# 1   1989JJ00  1989        None  Definitief
# 2   1990JJ00  1990        None  Definitief
# 3   1991JJ00  1991        None  Definitief
# 4   1992JJ00  1992        None  Definitief
# 5   1993JJ00  1993        None  Definitief
# 6   1994JJ00  1994        None  Definitief
# 7   1995JJ00  1995        None  Definitief
# 8   1996JJ00  1996        None  Definitief
# 9   1997JJ00  1997        None  Definitief
# 10  1998JJ00  1998        None  Definitief
# 11  1999JJ00  1999        None  Definitief
# 12  2000JJ00  2000        None  Definitief
# 13  2001JJ00  2001        None  Definitief
# 14  2002JJ00  2002        None  Definitief
# 15  2003JJ00  2003        None  Definitief
# 16  2004JJ00  2004        None  Definitief
# 17  2005JJ00  2005        None  Definitief
# 18  2006JJ00  2006        None  Definitief
# 19  2007JJ00  2007        None  Definitief
# 20  2008JJ00  2008        None  Definitief
# 21  2009JJ00  2009        None  Definitief
# 22  2010JJ00  2010        None  Definitief
# 23  2011JJ00  2011        None  Definitief
# 24  2012JJ00  2012        None  Definitief
# 25  2013JJ00  2013        None  Definitief
# 26  2014JJ00  2014        None  Definitief
# 27  2015JJ00  2015        None  Definitief
# 28  2016JJ00  2016        None  Definitief
# 29  2017JJ00  2017        None  Definitief
# 30  2018JJ00  2018        None  Definitief
# 31  2019JJ00  2019        None  Definitief

# %%
print(metadata['Description'][4])
# Out:
# Migratie per duizend van de gemiddelde bevolking in het waarnemingsjaar.
#
# Migratie:
# Verhuizing van personen van of naar een ander woonadres.
#
# Bevolking:
# De inwoners van een bepaald gebied.
# In de bevolkingsaantallen zijn uitsluitend personen begrepen die zijn opgenomen in het bevolkingsregister van een Nederlandse gemeente.
# In principe wordt iedereen die voor onbepaalde tijd in Nederland woont, opgenomen in het bevolkingsregister van de woongemeente.
# Personen die tot de bevolking van Nederland behoren, maar voor wie geen vaste woonplaats valt aan te wijzen, zijn opgenomen in het bevolkingsregister van de gemeente 's-Gravenhage.
# In de bevolkingsregisters zijn niet opgenomen de in Nederland wonende personen waarvoor uitzonderingsregels gelden met betrekking tot opneming in de bevolkingsregisters (bijvoorbeeld diplomaten en NAVO militairen) en personen die niet legaal in Nederland verblijven.
#
# Verwerking grenswijziging Rotterdam en Rozenburg in 2010
# Per 18 maart 2010 is de gemeente Rozenburg opgeheven en in zijn geheel overgegaan naar de gemeente Rotterdam.
# Voor de overzichtelijkheid zijn de cijfers met betrekking tot geboorte, sterfte, buitenlandse migratie en verhuizingen in Rozenburg voor geheel 2010 bij Rotterdam geteld.
# Voor Rozenburg zijn dus geen gegevens over de bevolkingsontwikkeling in 2010 beschikbaar.
# Voor de relatieve migratiecijfers van Rotterdam is steeds gerelateerd aan de bevolkingsaantallen van Rotterdam en Rozenburg samen.

# %%
# for 60056ned

# take only migratiesaldo from Migratie
filters = ["Nationaliteit eq 'NAT9489'", # total non-dutch
           "Nationaliteit eq 'NAT9275'", # total EU excl. Dutch
           "Nationaliteit eq 'NAT9482'", # total Western excl. Dutch
           "Nationaliteit eq 'NAT9483'"] # total Non-Western

data = pd.DataFrame()
for x in filters:
    data = data.append(pd.DataFrame(cbs.get_data('60056ned',
                                          select = ['TotaalMannen_22', 'RegioS', 'Perioden',
                                                    'TotaalVrouwen_34', 'EuropeseUnieExclusiefNederland_81',
                                                   'TotaalNietWesters_87', 'OverigeWesterseLanden_95', 
                                                   'NietNederlands_66', 'NietNederlandseVrouwen_69'],
                                         filters =  x)))

# %%
data
# Out:
#         TotaalMannen_22                           RegioS Perioden  \
# 0               48678.0                        Nederland     1988
# 1               53782.0                        Nederland     1989
# 2               65336.0                        Nederland     1990
# 3               66888.0                        Nederland     1991
# 4               63141.0                        Nederland     1992
# ...                 ...                              ...      ...
# 141915              NaN  Centraal persoonsregister (CPR)     2015
# 141916              NaN  Centraal persoonsregister (CPR)     2016
# 141917              NaN  Centraal persoonsregister (CPR)     2017
# 141918              NaN  Centraal persoonsregister (CPR)     2018
# 141919              NaN  Centraal persoonsregister (CPR)     2019
#
#         TotaalVrouwen_34  EuropeseUnieExclusiefNederland_81  \
# 0                42560.0                            15517.0
# 1                45132.0                            15645.0
# 2                52014.0                            18578.0
# 3                53361.0                            20164.0
# 4                53785.0                            21464.0
# ...                  ...                                ...
# 141915               NaN                                NaN
# 141916               NaN                                NaN
# 141917               NaN                                NaN
# 141918               NaN                                NaN
# 141919               NaN                                NaN
#
#         TotaalNietWesters_87  OverigeWesterseLanden_95  NietNederlands_66  \
# 0                    45300.0                   24952.0            32019.0
# 1                    50505.0                   26773.0            36699.0
# 2                    61483.0                   32368.0            46995.0
# 3                    60609.0                   35930.0            48379.0
# 4                    53139.0                   40208.0            45367.0
# ...                      ...                       ...                ...
# 141915                   NaN                       NaN                NaN
# 141916                   NaN                       NaN                NaN
# 141917                   NaN                       NaN                NaN
# 141918                   NaN                       NaN                NaN
# 141919                   NaN                       NaN                NaN
#
#         NietNederlandseVrouwen_69
# 0                         26243.0
# 1                         28686.0
# 2                         34269.0
# 3                         35958.0
# 4                         37655.0
# ...                           ...
# 141915                        NaN
# 141916                        NaN
# 141917                        NaN
# 141918                        NaN
# 141919                        NaN
#
# [567680 rows x 9 columns]

# %%
filters = ["Nationaliteit eq 'NAT9489'", # total non-dutch
           "Nationaliteit eq 'NAT9275'", # total EU excl. Dutch
           "Nationaliteit eq 'NAT9482'", # total Western excl. Dutch
           "Nationaliteit eq 'NAT9483'"] # total Non-Western

data = pd.DataFrame()
for x in filters:
    data = data.append(pd.DataFrame(cbs.get_data('84974NED',
                                          select = ['Geslacht', 'RegioS', 'Perioden',
                                                    'MigratiesaldoInclusiefAdministratie_3', 'Nationaliteit'],
                                         filters =  x)))

# %%
data
# Out:
#                         Geslacht     RegioS Perioden  \
# 0       Totaal mannen en vrouwen  Nederland     2010
# 1       Totaal mannen en vrouwen  Nederland     2011
# 2       Totaal mannen en vrouwen  Nederland     2012
# 3       Totaal mannen en vrouwen  Nederland     2013
# 4       Totaal mannen en vrouwen  Nederland     2014
# ...                          ...        ...      ...
# 185395                   Vrouwen     Zwolle     2015
# 185396                   Vrouwen     Zwolle     2016
# 185397                   Vrouwen     Zwolle     2017
# 185398                   Vrouwen     Zwolle     2018
# 185399                   Vrouwen     Zwolle     2019
#
#         MigratiesaldoInclusiefAdministratie_3  \
# 0                                     46191.0
# 1                                     48243.0
# 2                                     34916.0
# 3                                     39271.0
# 4                                     55905.0
# ...                                       ...
# 185395                                    1.0
# 185396                                   -1.0
# 185397                                    0.0
# 185398                                    0.0
# 185399                                    2.0
#
#                                 Nationaliteit
# 0       Totaal niet-Nederlandse nationaliteit
# 1       Totaal niet-Nederlandse nationaliteit
# 2       Totaal niet-Nederlandse nationaliteit
# 3       Totaal niet-Nederlandse nationaliteit
# 4       Totaal niet-Nederlandse nationaliteit
# ...                                       ...
# 185395          Niet-westerse nationaliteiten
# 185396          Niet-westerse nationaliteiten
# 185397          Niet-westerse nationaliteiten
# 185398          Niet-westerse nationaliteiten
# 185399          Niet-westerse nationaliteiten
#
# [741600 rows x 5 columns]

# %%
val = 'MigratiesaldoInclusiefAdministratie_3'
cat1 = 'Geslacht'
cat2 = 'Nationaliteit'
reg = 'RegioS'
year = 'Perioden'
data = split_column2(data, val, cat1, cat2, reg, year)

# %%
data.to_csv('Immigration.csv')

# %% [markdown]
# ## Downloading total immigrant numbers

# %% [markdown]
# alternatives
# 84910NED - current, from 2010
# 84727NED - current, from 1995

# %%
metadata = pd.DataFrame(cbs.get_meta('84727NED', 'DataProperties'))
metadata
# Out:
#                 odata.type  ID  Position ParentID           Type  \
# 0      Cbs.OData.Dimension   0         0     None      Dimension
# 1      Cbs.OData.Dimension   1         1     None      Dimension
# 2      Cbs.OData.Dimension   2         2     None      Dimension
# 3   Cbs.OData.GeoDimension   3         3     None   GeoDimension
# 4  Cbs.OData.TimeDimension   4         4     None  TimeDimension
# 5          Cbs.OData.Topic   5         5     None          Topic
#
#              Key          Title  \
# 0       Geslacht       Geslacht
# 1       Leeftijd       Leeftijd
# 2  Nationaliteit  Nationaliteit
# 3         RegioS        Regio's
# 4       Perioden       Perioden
# 5    Bevolking_1      Bevolking
#
#                                          Description  MapYear ReleasePolicy  \
# 0                                                         NaN           NaN
# 1  Het aantal gehele jaren dat op 1 januari van h...      NaN           NaN
# 2  Het wettelijk onderdaan zijn van een bepaalde ...      NaN           NaN
# 3                                                         NaN           NaN
# 4                                                         NaN         False
# 5  De inwoners van een bepaald gebied.\r\n\r\nIn ...      NaN           NaN
#
#   Datatype    Unit  Decimals     Default PresentationType
# 0      NaN     NaN       NaN         NaN              NaN
# 1      NaN     NaN       NaN         NaN              NaN
# 2      NaN     NaN       NaN         NaN              NaN
# 3      NaN     NaN       NaN         NaN              NaN
# 4      NaN     NaN       NaN         NaN              NaN
# 5     Long  aantal       0.0  Impossible         Absolute

# %%
print(metadata['Description'][2])
# Out:
# Persoon met een migratieachtergrond
#
# Persoon van wie ten minste één ouder in het buitenland is geboren.

# %%
filters = ["Migratieachtergrond eq '2012605'", # total non-dutch
           "Migratieachtergrond eq 'H007935'", # total EU excl. Dutch
           "Migratieachtergrond eq '2012655'", # total Western excl. Dutch
           "Migratieachtergrond eq '2012657'"] # total Non-Western

data = pd.DataFrame()
for x in filters:
    data = data.append(pd.DataFrame(cbs.get_data('84910NED',
                                          select = ['Geslacht', 'RegioS', 'Perioden', 'Migratieachtergrond',
                                                    'Generatie', 'BevolkingOp1Januari_1'],
                                         filters =  x)))

# %%
# Filter so that only first generation and only data on men and women is recorded
data = data[(data['Generatie'] == '1e generatie migratieachtergrond') & 
             ((data['Geslacht'] == 'Mannen') | 
             (data['Geslacht'] == 'Vrouwen'))].drop(['Generatie'], axis=1)

# %%
val = 'BevolkingOp1Januari_1'
cat1 = 'Geslacht'
cat2 = 'Migratieachtergrond'
reg = 'RegioS'
year = 'Perioden'
data = split_column2(data, val, cat1, cat2, reg, year)

# %%
data.to_csv('Total_Immigration.csv')

# %% [markdown]
# ## Downloading Income Data

# %% [markdown]
# alternatives:
# 80366ned is archive data, only has mean, from 2005 to 2014
# 84867NED is current, has mean and median from 2011
# 80500ned is archive, has mean and median from 2005 to 2014

# %%
metadata = pd.DataFrame(cbs.get_meta('80500ned', 'DataProperties'))
metadata
# Out:
#                 odata.type  ID  Position  ParentID           Type  \
# 0      Cbs.OData.Dimension   0       0.0       NaN      Dimension
# 1      Cbs.OData.Dimension   1       1.0       NaN      Dimension
# 2   Cbs.OData.GeoDimension   2       2.0       NaN   GeoDimension
# 3  Cbs.OData.TimeDimension   3       3.0       NaN  TimeDimension
# 4     Cbs.OData.TopicGroup   4       NaN       NaN     TopicGroup
# 5          Cbs.OData.Topic   5       4.0       4.0          Topic
# 6          Cbs.OData.Topic   6       5.0       4.0          Topic
# 7          Cbs.OData.Topic   7       6.0       NaN          Topic
# 8          Cbs.OData.Topic   8       7.0       NaN          Topic
#
#                              Key                          Title  \
# 0                      Populatie                      Populatie
# 1              Persoonskenmerken              Persoonskenmerken
# 2                         RegioS                        Regio's
# 3                       Perioden                       Perioden
# 4                                          Personen met inkomen
# 5               AantalPersonen_1                Aantal personen
# 6       RelatiefAantalPersonen_2       Relatief aantal personen
# 7  GemiddeldPersoonlijkInkomen_3  Gemiddeld persoonlijk inkomen
# 8    MediaanPersoonlijkInkomen_4    Mediaan persoonlijk inkomen
#
#                                          Description  MapYear ReleasePolicy  \
# 0                                               None      NaN           NaN
# 1                                               None      NaN           NaN
# 2                                                      2011.0           NaN
# 3                                               None      NaN         False
# 4                                               None      NaN           NaN
# 5  Een persoon heeft inkomen, indien er sprake is...      NaN           NaN
# 6  Aantal personen met (heel jaar) inkomen in pro...      NaN           NaN
# 7  Het persoonlijk inkomen omvat de volgende best...      NaN           NaN
# 8  Het mediane inkomen is gelijk aan het middelst...      NaN           NaN
#
#   Datatype        Unit  Decimals     Default PresentationType
# 0      NaN         NaN       NaN         NaN              NaN
# 1      NaN         NaN       NaN         NaN              NaN
# 2      NaN         NaN       NaN         NaN              NaN
# 3      NaN         NaN       NaN         NaN              NaN
# 4      NaN         NaN       NaN         NaN              NaN
# 5   Double     x 1 000       1.0  Impossible         Absolute
# 6   Double           %       1.0  Impossible         Relative
# 7   Double  1 000 euro       1.0  Impossible         Relative
# 8   Double  1 000 euro       1.0  Impossible         Relative

# %%
print(metadata['Description'][4])
# Out:
# Met ingang van het RIO 2010 zijn de resultaten gebaseerd op integrale waarneming. De eerder gepubliceerde resultaten van het RIO (2005 – 2009 voor methodewijziging) zijn gebaseerd op een steekproef van ca. 2 miljoen huishoudens.
# Om vergelijking tussen 2010 integraal en 2009 steekproef mogelijk te maken zijn voor 2009 na methodewijziging eveneens op basis van integrale waarneming uitkomsten gepubliceerd waardoor voor het jaar 2009 (breukjaar) zowel uitkomsten op basis van steekproef als integrale waarneming zijn opgenomen.

# %%
data = pd.DataFrame(cbs.get_data('84867NED',
                                      select = ['Geslacht', 'RegioS', 'Perioden',
                                                'Persoonskenmerken', 'GemiddeldGestandaardiseerdInkomen_4',
                                                'MediaanGestandaardiseerdInkomen_5'],
                                     filters = "Persoonskenmerken eq 'T009002'"))

# %%
val = ['GemiddeldGestandaardiseerdInkomen_4', 'MediaanGestandaardiseerdInkomen_5']
cat = 'Geslacht'
reg = 'RegioS'
year = 'Perioden'
data = split_column(data, val, cat, reg, year)

# %%
data.to_csv('Income.csv')

# %% [markdown]
# ## Downloading Marriage Data

# %%
metadata = pd.DataFrame(cbs.get_meta('37890', 'DataProperties'))
metadata
# Out:
#                   odata.type   ID  Position  ParentID           Type  \
# 0     Cbs.OData.GeoDimension    0       0.0       NaN   GeoDimension
# 1    Cbs.OData.TimeDimension    1       1.0       NaN  TimeDimension
# 2       Cbs.OData.TopicGroup    2       NaN       NaN     TopicGroup
# 3       Cbs.OData.TopicGroup    3       NaN       2.0     TopicGroup
# 4            Cbs.OData.Topic    4       2.0       3.0          Topic
# 5            Cbs.OData.Topic    5       3.0       3.0          Topic
# 6            Cbs.OData.Topic    6       4.0       3.0          Topic
# 7            Cbs.OData.Topic    7       5.0       3.0          Topic
# 8            Cbs.OData.Topic    8       6.0       3.0          Topic
# 9       Cbs.OData.TopicGroup    9       NaN       2.0     TopicGroup
# 10           Cbs.OData.Topic   10       7.0       9.0          Topic
# 11           Cbs.OData.Topic   11       8.0       9.0          Topic
# 12           Cbs.OData.Topic   12       9.0       9.0          Topic
# 13           Cbs.OData.Topic   13      10.0       9.0          Topic
# 14      Cbs.OData.TopicGroup   14       NaN       9.0     TopicGroup
# 15      Cbs.OData.TopicGroup   15       NaN      14.0     TopicGroup
# 16           Cbs.OData.Topic   16      11.0      15.0          Topic
# 17           Cbs.OData.Topic   17      12.0      15.0          Topic
# 18           Cbs.OData.Topic   18      13.0      15.0          Topic
# 19           Cbs.OData.Topic   19      14.0      15.0          Topic
# 20           Cbs.OData.Topic   20      15.0      15.0          Topic
# 21           Cbs.OData.Topic   21      16.0      15.0          Topic
# 22           Cbs.OData.Topic   22      17.0      15.0          Topic
# 23           Cbs.OData.Topic   23      18.0      15.0          Topic
# 24           Cbs.OData.Topic   24      19.0      15.0          Topic
# 25           Cbs.OData.Topic   25      20.0      15.0          Topic
# 26           Cbs.OData.Topic   26      21.0      15.0          Topic
# 27           Cbs.OData.Topic   27      22.0      15.0          Topic
# 28      Cbs.OData.TopicGroup   28       NaN      14.0     TopicGroup
# 29           Cbs.OData.Topic   29      23.0      28.0          Topic
# 30           Cbs.OData.Topic   30      24.0      28.0          Topic
# 31           Cbs.OData.Topic   31      25.0      28.0          Topic
# 32           Cbs.OData.Topic   32      26.0      28.0          Topic
# 33           Cbs.OData.Topic   33      27.0      28.0          Topic
# 34           Cbs.OData.Topic   34      28.0      28.0          Topic
# 35           Cbs.OData.Topic   35      29.0      28.0          Topic
# 36           Cbs.OData.Topic   36      30.0      28.0          Topic
# 37           Cbs.OData.Topic   37      31.0      28.0          Topic
# 38           Cbs.OData.Topic   38      32.0      28.0          Topic
# 39           Cbs.OData.Topic   39      33.0      28.0          Topic
# 40           Cbs.OData.Topic   40      34.0      28.0          Topic
# 41      Cbs.OData.TopicGroup   41       NaN       9.0     TopicGroup
# 42      Cbs.OData.TopicGroup   42       NaN      41.0     TopicGroup
# 43           Cbs.OData.Topic   43      35.0      42.0          Topic
# 44           Cbs.OData.Topic   44      36.0      42.0          Topic
# 45           Cbs.OData.Topic   45      37.0      42.0          Topic
# 46           Cbs.OData.Topic   46      38.0      42.0          Topic
# 47           Cbs.OData.Topic   47      39.0      42.0          Topic
# 48      Cbs.OData.TopicGroup   48       NaN      41.0     TopicGroup
# 49           Cbs.OData.Topic   49      40.0      48.0          Topic
# 50           Cbs.OData.Topic   50      41.0      48.0          Topic
# 51           Cbs.OData.Topic   51      42.0      48.0          Topic
# 52           Cbs.OData.Topic   52      43.0      48.0          Topic
# 53           Cbs.OData.Topic   53      44.0      48.0          Topic
# 54      Cbs.OData.TopicGroup   54       NaN       NaN     TopicGroup
# 55           Cbs.OData.Topic   55      45.0      54.0          Topic
# 56           Cbs.OData.Topic   56      46.0      54.0          Topic
# 57           Cbs.OData.Topic   57      47.0      54.0          Topic
# 58           Cbs.OData.Topic   58      48.0      54.0          Topic
# 59      Cbs.OData.TopicGroup   59       NaN      54.0     TopicGroup
# 60      Cbs.OData.TopicGroup   60       NaN      59.0     TopicGroup
# 61           Cbs.OData.Topic   61      49.0      60.0          Topic
# 62           Cbs.OData.Topic   62      50.0      60.0          Topic
# 63           Cbs.OData.Topic   63      51.0      60.0          Topic
# 64           Cbs.OData.Topic   64      52.0      60.0          Topic
# 65           Cbs.OData.Topic   65      53.0      60.0          Topic
# 66           Cbs.OData.Topic   66      54.0      60.0          Topic
# 67           Cbs.OData.Topic   67      55.0      60.0          Topic
# 68           Cbs.OData.Topic   68      56.0      60.0          Topic
# 69           Cbs.OData.Topic   69      57.0      60.0          Topic
# 70      Cbs.OData.TopicGroup   70       NaN      59.0     TopicGroup
# 71           Cbs.OData.Topic   71      58.0      70.0          Topic
# 72           Cbs.OData.Topic   72      59.0      70.0          Topic
# 73           Cbs.OData.Topic   73      60.0      70.0          Topic
# 74           Cbs.OData.Topic   74      61.0      70.0          Topic
# 75           Cbs.OData.Topic   75      62.0      70.0          Topic
# 76           Cbs.OData.Topic   76      63.0      70.0          Topic
# 77           Cbs.OData.Topic   77      64.0      70.0          Topic
# 78           Cbs.OData.Topic   78      65.0      70.0          Topic
# 79           Cbs.OData.Topic   79      66.0      70.0          Topic
# 80      Cbs.OData.TopicGroup   80       NaN       NaN     TopicGroup
# 81           Cbs.OData.Topic   81      67.0      80.0          Topic
# 82           Cbs.OData.Topic   82      68.0      80.0          Topic
# 83           Cbs.OData.Topic   83      69.0      80.0          Topic
# 84           Cbs.OData.Topic   84      70.0      80.0          Topic
# 85      Cbs.OData.TopicGroup   85       NaN      80.0     TopicGroup
# 86      Cbs.OData.TopicGroup   86       NaN      85.0     TopicGroup
# 87           Cbs.OData.Topic   87      71.0      86.0          Topic
# 88           Cbs.OData.Topic   88      72.0      86.0          Topic
# 89           Cbs.OData.Topic   89      73.0      86.0          Topic
# 90           Cbs.OData.Topic   90      74.0      86.0          Topic
# 91           Cbs.OData.Topic   91      75.0      86.0          Topic
# 92           Cbs.OData.Topic   92      76.0      86.0          Topic
# 93           Cbs.OData.Topic   93      77.0      86.0          Topic
# 94      Cbs.OData.TopicGroup   94       NaN      85.0     TopicGroup
# 95           Cbs.OData.Topic   95      78.0      94.0          Topic
# 96           Cbs.OData.Topic   96      79.0      94.0          Topic
# 97           Cbs.OData.Topic   97      80.0      94.0          Topic
# 98           Cbs.OData.Topic   98      81.0      94.0          Topic
# 99           Cbs.OData.Topic   99      82.0      94.0          Topic
# 100          Cbs.OData.Topic  100      83.0      94.0          Topic
# 101          Cbs.OData.Topic  101      84.0      94.0          Topic
#
#                                        Key  \
# 0                                   RegioS
# 1                                 Perioden
# 2
# 3
# 4              TotaalHuwelijkssluitingen_1
# 5         BeidenWonenInHuwelijksgemeente_2
# 6      AlleenManWoontInHuwelijksgemeente_3
# 7    AlleenVrouwWoontInHuwelijksgemeente_4
# 8     BeidenWonenNietInHuwelijksgemeente_5
# 9
# 10                         HuwendeMannen_6
# 11                 HuwendeMannenRelatief_7
# 12                        HuwendeVrouwen_8
# 13                HuwendeVrouwenRelatief_9
# 14
# 15
# 16                  TotaalHuwendeMannen_10
# 17                      JongerDan20Jaar_11
# 18                        k_20Tot25Jaar_12
# 19                        k_25Tot30Jaar_13
# 20                        k_30Tot35Jaar_14
# 21                        k_35Tot40Jaar_15
# 22                        k_40Tot45Jaar_16
# 23                        k_45Tot50Jaar_17
# 24                        k_50Tot55Jaar_18
# 25                        k_55Tot60Jaar_19
# 26                        k_60Tot65Jaar_20
# 27                      k_65JaarOfOuder_21
# 28
# 29                 TotaalHuwendeVrouwen_22
# 30                      JongerDan20Jaar_23
# 31                        k_20Tot25Jaar_24
# 32                        k_25Tot30Jaar_25
# 33                        k_30Tot35Jaar_26
# 34                        k_35Tot40Jaar_27
# 35                        k_40Tot45Jaar_28
# 36                        k_45Tot50Jaar_29
# 37                        k_50Tot55Jaar_30
# 38                        k_55Tot60Jaar_31
# 39                        k_60Tot65Jaar_32
# 40                      k_65JaarOfOuder_33
# 41
# 42
# 43                  TotaalHuwendeMannen_34
# 44                             Ongehuwd_35
# 45                         Partnerschap_36
# 46                            Verweduwd_37
# 47                           Gescheiden_38
# 48
# 49                 TotaalHuwendeVrouwen_39
# 50                             Ongehuwd_40
# 51                         Partnerschap_41
# 52                            Verweduwd_42
# 53                           Gescheiden_43
# 54
# 55              VanEchtScheidendeMannen_44
# 56      VanEchtScheidendeMannenRelatief_45
# 57             VanEchtScheidendeVrouwen_46
# 58     VanEchtScheidendeVrouwenRelatief_47
# 59
# 60
# 61        TotaalVanEchtScheidendeMannen_48
# 62                      JongerDan30Jaar_49
# 63                        k_30Tot35Jaar_50
# 64                        k_35Tot40Jaar_51
# 65                        k_40Tot45Jaar_52
# 66                        k_45Tot50Jaar_53
# 67                        k_50Tot55Jaar_54
# 68                        k_55Tot60Jaar_55
# 69                      k_60JaarOfOuder_56
# 70
# 71       TotaalVanEchtScheidendeVrouwen_57
# 72                      JongerDan30Jaar_58
# 73                        k_30Tot35Jaar_59
# 74                        k_35Tot40Jaar_60
# 75                        k_40Tot45Jaar_61
# 76                        k_45Tot50Jaar_62
# 77                        k_50Tot55Jaar_63
# 78                        k_55Tot60Jaar_64
# 79                      k_60JaarOfOuder_65
# 80
# 81                   VerweduwendeMannen_66
# 82           VerweduwendeMannenRelatief_67
# 83                  VerweduwendeVrouwen_68
# 84          VerweduwendeVrouwenRelatief_69
# 85
# 86
# 87             TotaalVerweduwendeMannen_70
# 88                      JongerDan45Jaar_71
# 89                        k_45Tot55Jaar_72
# 90                        k_55Tot65Jaar_73
# 91                        k_65Tot75Jaar_74
# 92                        k_75Tot85Jaar_75
# 93                      k_85JaarOfOuder_76
# 94
# 95            TotaalVerweduwendeVrouwen_77
# 96                      JongerDan45Jaar_78
# 97                        k_45Tot55Jaar_79
# 98                        k_55Tot65Jaar_80
# 99                        k_65Tot75Jaar_81
# 100                       k_75Tot85Jaar_82
# 101                     k_85JaarOfOuder_83
#
#                                        Title  \
# 0                                    Regio's
# 1                                   Perioden
# 2                                      Huwen
# 3                        Huwelijkssluitingen
# 4                 Totaal huwelijkssluitingen
# 5          Beiden wonen in huwelijksgemeente
# 100                           75 tot 85 jaar
# 101                         85 jaar of ouder
#
#                                            Description  MapYear ReleasePolicy  \
# 0                                                 None      NaN           NaN
# 1                                                 None      NaN         False
# 2    Trendbreuk huwelijkssluitingen en huwende pers...      NaN           NaN
# 3    Trendbreuk huwelijkssluitingen en huwende pers...      NaN           NaN
# 4                                                 None      NaN           NaN
# 5    Huwelijksluitingen waarvan beide partners staa...      NaN           NaN
# 6    Huwelijkssluitingen waarvan alleen de man staa...      NaN           NaN
# 7    Huwelijkssluitingen waarvan alleen de vrouw st...      NaN           NaN
# 8    Huwelijkssluitingen waarvan beide partners NIE...      NaN           NaN
# 9    Trendbreuk huwelijkssluitingen en huwende pers...      NaN           NaN
# 10                                                None      NaN           NaN
# 11   Huwende mannen per duizend van het gemiddeld a...      NaN           NaN
# 12                                                None      NaN           NaN
# 13   Huwende vrouwen per duizend van het gemiddeld ...      NaN           NaN
# 14   Huwende personen naar geslacht en leeftijd (op...      NaN           NaN
# 15                                                None      NaN           NaN
# 16                                                None      NaN           NaN
# 17                                                None      NaN           NaN
# 18                                                None      NaN           NaN
# 19                                                None      NaN           NaN
# 20                                                None      NaN           NaN
# 21                                                None      NaN           NaN
# 22                                                None      NaN           NaN
# 23                                                None      NaN           NaN
# 24                                                None      NaN           NaN
# 25                                                None      NaN           NaN
# 26                                                None      NaN           NaN
# 27                                                None      NaN           NaN
# 28                                                None      NaN           NaN
# 29                                                None      NaN           NaN
# 30                                                None      NaN           NaN
# 31                                                None      NaN           NaN
# 32                                                None      NaN           NaN
# 33                                                None      NaN           NaN
# 34                                                None      NaN           NaN
# 35                                                None      NaN           NaN
# 36                                                None      NaN           NaN
# 37                                                None      NaN           NaN
# 38                                                None      NaN           NaN
# 39                                                None      NaN           NaN
# 40                                                None      NaN           NaN
# 41   Huwende personen naar geslacht en burgerlijke ...      NaN           NaN
# 42                                                None      NaN           NaN
# 43                                                None      NaN           NaN
# 44   Vanaf 2010: burgerlijke staat die aangeeft dat...      NaN           NaN
# 45   Mannen die hun geregistreerd partnerschap hebb...      NaN           NaN
# 46   Vanaf 2010: verweduwd na wettig huwelijk plus ...      NaN           NaN
# 47   Vanaf 2010: gescheiden na wettig huwelijk plus...      NaN           NaN
# 48                                                None      NaN           NaN
# 49                                                None      NaN           NaN
# 50   Vanaf 2010: burgerlijke staat die aangeeft dat...      NaN           NaN
# 51   Vrouwen die hun geregistreerd partnerschap heb...      NaN           NaN
# 52   Vanaf 2010: verweduwd na wettig huwelijk plus ...      NaN           NaN
# 53   Vanaf 2010: gescheiden na wettig huwelijk plus...      NaN           NaN
# 54   Van echt scheidende persoon:\r\nPersoon van wi...      NaN           NaN
# 55                                                None      NaN           NaN
# 56   Van echt scheidende mannen per duizend van het...      NaN           NaN
# 57                                                None      NaN           NaN
# 58   Van echt scheidende vrouwen per duizend van he...      NaN           NaN
# 59   Van echt scheidende personen naar geslacht en ...      NaN           NaN
# 60                                                None      NaN           NaN
# 61                                                          NaN           NaN
# 62                                                None      NaN           NaN
# 63                                                None      NaN           NaN
# 64                                                None      NaN           NaN
# 65                                                None      NaN           NaN
# 66                                                None      NaN           NaN
# 67                                                None      NaN           NaN
# 68                                                None      NaN           NaN
# 69                                                None      NaN           NaN
# 70                                                None      NaN           NaN
# 71                                                None      NaN           NaN
# 72                                                None      NaN           NaN
# 73                                                None      NaN           NaN
# 74                                                None      NaN           NaN
# 75                                                None      NaN           NaN
# 76                                                None      NaN           NaN
# 77                                                None      NaN           NaN
# 78                                                None      NaN           NaN
# 79                                                None      NaN           NaN
# 80   Verweduwende persoon:\r\nPersoon van wie het h...      NaN           NaN
# 81                                                None      NaN           NaN
# 82   Verweduwde mannen per duizend van het gemiddel...      NaN           NaN
# 83                                                None      NaN           NaN
# 84   Verweduwde vrouwen per duizend van het gemidde...      NaN           NaN
# 85   Verweduwende personen naar geslacht en leeftij...      NaN           NaN
# 86                                                None      NaN           NaN
# 87                                                None      NaN           NaN
# 88                                                None      NaN           NaN
# 89                                                None      NaN           NaN
# 90                                                None      NaN           NaN
# 91                                                None      NaN           NaN
# 92                                                None      NaN           NaN
# 93                                                None      NaN           NaN
# 94                                                None      NaN           NaN
# 95                                                None      NaN           NaN
# 96                                                None      NaN           NaN
# 97                                                None      NaN           NaN
# 98                                                None      NaN           NaN
# 99                                                None      NaN           NaN
# 100                                               None      NaN           NaN
# 101                                               None      NaN           NaN
#
#     Datatype                            Unit  Decimals     Default  \
# 0        NaN                             NaN       NaN         NaN
# 1        NaN                             NaN       NaN         NaN
# 2        NaN                             NaN       NaN         NaN
# 3        NaN                             NaN       NaN         NaN
# 4       Long                          aantal       0.0  Impossible
# 5       Long                          aantal       0.0  Impossible
# 6       Long                          aantal       0.0  Impossible
# 7       Long                          aantal       0.0  Impossible
# 8       Long                          aantal       0.0  Impossible
# 9        NaN                             NaN       NaN         NaN
# 10      Long                          aantal       0.0  Impossible
# 11    Double   per 1 000 niet-gehuwde mannen       1.0  Impossible
# 12      Long                          aantal       0.0  Impossible
# 13    Double  per 1 000 niet-gehuwde vrouwen       1.0  Impossible
# 14       NaN                             NaN       NaN         NaN
# 15       NaN                             NaN       NaN         NaN
# 16      Long                          aantal       0.0  Impossible
# 17      Long                          aantal       0.0  Impossible
# 18      Long                          aantal       0.0  Impossible
# 19      Long                          aantal       0.0  Impossible
# 20      Long                          aantal       0.0  Impossible
# 21      Long                          aantal       0.0  Impossible
# 22      Long                          aantal       0.0  Impossible
# 23      Long                          aantal       0.0  Impossible
# 24      Long                          aantal       0.0  Impossible
# 25      Long                          aantal       0.0  Impossible
# 26      Long                          aantal       0.0  Impossible
# 27      Long                          aantal       0.0  Impossible
# 28       NaN                             NaN       NaN         NaN
# 29      Long                          aantal       0.0  Impossible
# 30      Long                          aantal       0.0  Impossible
# 31      Long                          aantal       0.0  Impossible
# 32      Long                          aantal       0.0  Impossible
# 33      Long                          aantal       0.0  Impossible
# 34      Long                          aantal       0.0  Impossible
# 35      Long                          aantal       0.0  Impossible
# 36      Long                          aantal       0.0  Impossible
# 37      Long                          aantal       0.0  Impossible
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4           Absolute
# 5           Absolute
# 6           Absolute
# 7           Absolute
# 8           Absolute
# 9                NaN
# 10          Absolute
# 11          Relative
# 12          Absolute
# 13          Relative
# 14               NaN
# 15               NaN
# 16          Absolute
# 17          Absolute
# 18          Absolute
# 19          Absolute
# 20          Absolute
# 21          Absolute
# 22          Absolute
# 23          Absolute
# 24          Absolute
# 25          Absolute
# 26          Absolute
# 27          Absolute
# 28               NaN
# 29          Absolute
# 30          Absolute
# 31          Absolute
# 32          Absolute
# 33          Absolute
# 34          Absolute
# 35          Absolute
# 36          Absolute
# 37          Absolute
# 38          Absolute
# 39          Absolute
# 40          Absolute
# 41               NaN
# 42               NaN
# 43          Absolute
# 44          Absolute
# 45          Absolute
# 46          Absolute
# 47          Absolute
# 48               NaN
# 49          Absolute
# 50          Absolute
# 51          Absolute
# 52          Absolute
# 53          Absolute
# 54               NaN
# 55          Absolute
# 56          Relative
# 57          Absolute
# 58          Relative
# 59               NaN
# 60               NaN
# 61          Absolute
# 62          Absolute
# 63          Absolute
# 64          Absolute
# 65          Absolute
# 66          Absolute
# 67          Absolute
# 68          Absolute
# 69          Absolute
# 70               NaN
# 71          Absolute
# 72          Absolute
# 73          Absolute
# 74          Absolute
# 75          Absolute
# 76          Absolute
# 77          Absolute
# 78          Absolute
# 79          Absolute
# 80               NaN
# 81          Absolute
# 82          Relative
# 83          Absolute
# 84          Relative
# 85               NaN
# 86               NaN
# 87          Absolute
# 88          Absolute
# 89          Absolute
# 90          Absolute
# 91          Absolute
# 92          Absolute
# 93          Absolute
# 94               NaN
# 95          Absolute
# 96          Absolute
# 97          Absolute
# 98          Absolute
# 99          Absolute
# 100         Absolute
# 101         Absolute

# %%
print(metadata['Description'][11])
# Out:
# Huwende mannen per duizend van het gemiddeld aantal niet gehuwde mannen van 15 jaar of ouder, gestandaardiseerd naar leeftijd.
#
# Standaardisatie:
# Bij standaardisatie wordt de invloed van de bevolking naar leeftijd uitgeschakeld. De functie van standaardisatie is het beter vergelijkbaar maken van cijfers tussen de verschillende gemeenten, regio's en Nederland.
# De bevolking van Nederland als geheel heeft als standaardbevolking gediend.
#
# Leeftijd:
# Het aantal gehele jaren dat op 31 december in het jaar van huwelijkssluiting is verstreken sinds de geboortedatum van de persoon. Te berekenen als jaar van huwelijkssluiting min geboortejaar.
#
# Gemiddeld aantal niet-gehuwde mannen:
# De helft van het aantal niet-gehuwde mannen met een bepaald geboortejaar aan het begin van een periode plus de helft van de niet-gehuwde mannen met dat zelfde geboortejaar aan het einde van de periode.

# %%
data = pd.DataFrame(cbs.get_data('37890',
                                      select = ['RegioS', 'Perioden',
                                                'TotaalHuwelijkssluitingen_1', 'HuwendeMannenRelatief_7',
                                                'HuwendeVrouwenRelatief_9']))

# Making RegioS and Perioden the index values as in other dataframes

data.index = pd.MultiIndex.from_arrays(data[['RegioS', 'Perioden']].values.T, names=['RegioS', 'Perioden'])
data = data.drop(['RegioS', 'Perioden'], axis=1)

data.to_csv('Marriage.csv')

# %% [markdown]
# ## Downloading Crime Data

# %% [markdown]
# alternatives:
# 83648NED is current, very detailed crime, also per 1000 people
#
# 83223NED is archive, less detailed, but still ok, problem: only has registered cases with at least 1 suspect

# %%
metadata = pd.DataFrame(cbs.get_meta('83648NED', 'RegioS'))
metadata
# Out:
#         Key                              Title  \
# 0    NL01                            Nederland
# 1    LD01                 Noord-Nederland (LD)
# 2    LD02                  Oost-Nederland (LD)
# 3    LD03                  West-Nederland (LD)
# 4    LDG4    West-Nederland, exclusief G4 (LD)
# 5    LD04                  Zuid-Nederland (LD)
# 6    LD99                Niet in te delen (LD)
# 7    PV20                       Groningen (PV)
# 8    PV21                         Fryslân (PV)
# 9    PV22                         Drenthe (PV)
# 10   PV23                      Overijssel (PV)
# 11   PV24                       Flevoland (PV)
# 12   PV25                      Gelderland (PV)
# 13   PV26                         Utrecht (PV)
# 14   PV27                   Noord-Holland (PV)
# 15   PV28                    Zuid-Holland (PV)
# 16   PV29                         Zeeland (PV)
# 17   PV30                   Noord-Brabant (PV)
# 18   PV31                         Limburg (PV)
# 19   PV99                Niet in te delen (PV)
# 20   GM1680                        Aa en Hunze
# 21   GM0738                            Aalburg
# 22   GM0358                           Aalsmeer
# 23   GM0197                             Aalten
# 24   GM0305                            Abcoude
# 25   GM0059                      Achtkarspelen
# 26   GM0482                       Alblasserdam
# 27   GM0613                      Albrandswaard
# 28   GM0361                            Alkmaar
# 29   GM0141                             Almelo
# 30   GM0034                             Almere
# 31   GM0484                Alphen aan den Rijn
# 32   GM1723                       Alphen-Chaam
# 33   GM1959                             Altena
# 34   GM0060                            Ameland
# 35   GM0307                         Amersfoort
# 36   GM0362                         Amstelveen
# 37   GM0363                          Amsterdam
# 38   GM0364                             Andijk
# 39   GM0366                      Anna Paulowna
# 40   GM0200                          Apeldoorn
# 41   GM0003                         Appingedam
# 42   GM0202                             Arnhem
# 43   GM0106                              Assen
# 44   GM0743                              Asten
# 45   GM0744                      Baarle-Nassau
# 46   GM0308                              Baarn
# 47   GM0489                        Barendrecht
# 48   GM0203                          Barneveld
# 49   GM0005                              Bedum
# 50   GM0888                          Beek (L.)
# 51   GM1954                         Beekdaelen
# 52   GM0370                           Beemster
# 53   GM0889                             Beesel
# 54   GM0007                       Bellingwedde
# 55   GM1945                        Berg en Dal
# 56   GM0491                        Bergambacht
# 57   GM1724                           Bergeijk
# 58   GM0893                        Bergen (L.)
# 59   GM0373                       Bergen (NH.)
# 60   GM0748                     Bergen op Zoom
# 61   GM1859                         Berkelland
# 62   GM1721                           Bernheze
# 63   GM0568                           Bernisse
# 64   GM0753                               Best
# 65   GM0209                          Beuningen
# 66   GM0375                          Beverwijk
# 67   GM0063                          het Bildt
# 68   GM0310                            De Bilt
# 69   GM0585                         Binnenmaas
# 70   GM1728                             Bladel
# 71   GM0376                           Blaricum
# 72   GM0377                        Bloemendaal
# 73   GM0055                       Boarnsterhim
# 74   GM0497                         Bodegraven
# 75   GM1901                Bodegraven-Reeuwijk
# 76   GM0755                             Boekel
# 77   GM0009                           Ten Boer
# 78   GM0064                           Bolsward
# 79   GM1681                      Borger-Odoorn
# 80   GM0147                              Borne
# 81   GM0654                            Borsele
# 82   GM0499                            Boskoop
# 83   GM0756                            Boxmeer
# 84   GM0757                             Boxtel
# 85   GM0758                              Breda
# 86   GM0311                          Breukelen
# 443  GM0614                         Westvoorne
# 444  GM0189                            Wierden
# 445  GM0462                          Wieringen
# 446  GM0463                      Wieringermeer
# 447  GM0296                            Wijchen
# 448  GM1696                         Wijdemeren
# 449  GM0352                 Wijk bij Duurstede
# 450  GM0053                             Winsum
# 451  GM0294                        Winterswijk
# 452  GM0873                        Woensdrecht
# 453  GM0632                            Woerden
# 454  GM1690                          De Wolden
# 455  GM0880                         Wormerland
# 456  GM0351                         Woudenberg
# 457  GM0874                         Woudrichem
# 458  GM0710                        Wûnseradiel
# 459  GM0683                    Wymbritseradiel
# 460  GM0479                           Zaanstad
# 461  GM0297                         Zaltbommel
# 462  GM0473                          Zandvoort
# 463  GM0707                            Zederik
# 464  GM0478                            Zeevang
# 465  GM0050                           Zeewolde
# 466  GM0355                              Zeist
# 467  GM0299                           Zevenaar
# 468  GM0476                              Zijpe
# 469  GM0637                         Zoetermeer
# 470  GM0638                        Zoeterwoude
# 471  GM0056                           Zuidhorn
# 472  GM1892                           Zuidplas
# 473  GM0879                            Zundert
# 474  GM0301                            Zutphen
# 475  GM1896                    Zwartewaterland
# 476  GM0642                        Zwijndrecht
# 477  GM0193                             Zwolle
# 478  GM0999        Niet-gemeentelijk ingedeeld
# 479  RE01                 Noord-Nederland (RE)
# 480  RE02                  Oost-Nederland (RE)
# 481  RE03                Midden-Nederland (RE)
# 482  RE04                   Noord-Holland (RE)
# 483  RE05                       Amsterdam (RE)
# 484  RE06                        Den Haag (RE)
# 485  RE07                       Rotterdam (RE)
# 486  RE08          Zeeland - West-Brabant (RE)
# 487  RE09                    Oost-Brabant (RE)
# 488  RE10                         Limburg (RE)
# 489  RE99                Niet in te delen (RE)
#
#                                            Description CategoryGroupID
# 0                                                                 None
# 1    LD = Landsdeel\r\n\r\nNoord-Nederland: Groning...            None
# 2    LD = Landsdeel\r\n\r\nOost-Nederland: Overijss...            None
# 3    LD = Landsdeel\r\n\r\nWest-Nederland: Utrecht,...            None
# 4    LD = Landsdeel\r\n\r\nWest-Nederland: Utrecht,...            None
# 5    LD = Landsdeel\r\n\r\nZuid-Nederland: Noord-Br...            None
# 6    LD = Landsdeel\r\n\r\nRegionale groepering van...            None
# 7    PV = Provincie\r\n\r\nBestuurlijke onderverdel...            None
# 8    PV = Provincie\r\n\r\nBestuurlijke onderverdel...            None
# 9    PV = Provincie\r\n\r\nBestuurlijke onderverdel...            None
# 10   PV = Provincie\r\n\r\nBestuurlijke onderverdel...            None
# 11   PV = Provincie\r\n\r\nBestuurlijke onderverdel...            None
# 12   PV = Provincie\r\n\r\nBestuurlijke onderverdel...            None
# 13   PV = Provincie\r\n\r\nBestuurlijke onderverdel...            None
# 14   PV = Provincie\r\n\r\nBestuurlijke onderverdel...            None
# 15   PV = Provincie\r\n\r\nBestuurlijke onderverdel...            None
# 16   PV = Provincie\r\n\r\nBestuurlijke onderverdel...            None
# 17   PV = Provincie\r\n\r\nBestuurlijke onderverdel...            None
# 18   PV = Provincie\r\n\r\nBestuurlijke onderverdel...            None
# 441                            Ontstaan per 01-01-2004            None
# 442                               Begindatum voor 1830            None
# 443                            Ontstaan per 01-01-1980            None
# 444                               Begindatum voor 1830            None
# 445   Opgeheven per 01-01-2012\r\nBegindatum voor 1830            None
# 446  Opgeheven per 01-01-2012\r\nOntstaan per 01-01...            None
# 447                               Begindatum voor 1830            None
# 448                            Ontstaan per 01-01-2002            None
# 449  Gemeentelijke herindeling per 01-01-1996\r\nBe...            None
# 450   Opgeheven per 01-01-2019\r\nBegindatum voor 1830            None
# 451                               Begindatum voor 1830            None
# 452  Gemeentelijke herindeling per 01-01-1997\r\nBe...            None
# 453  Gemeentelijke herindeling per 01-01-2001\r\nPr...            None
# 454                            Ontstaan per 01-01-1998            None
# 455                            Ontstaan per 01-01-1991            None
# 456                               Begindatum voor 1830            None
# 457   Opgeheven per 01-01-2019\r\nBegindatum voor 1830            None
# 458  Opgeheven per 01-01-2011\r\nNaamswijziging per...            None
# 459  Opgeheven per 01-01-2011\r\nNaamswijziging per...            None
# 460                            Ontstaan per 01-01-1974            None
# 461  Gemeentelijke herindeling per 01-01-1999\r\nBe...            None
# 462                               Begindatum voor 1830            None
# 463  Opgeheven per 01-01-2019\r\nProvinciale wijzig...            None
# 464  Opgeheven per 01-01-2016\r\nOntstaan per 01-08...            None
# 465                            Ontstaan per 01-01-1984            None
# 466                               Begindatum voor 1830            None
# 467  Gemeentelijke herindeling per 01-01-2018\r\nGe...            None
# 468   Opgeheven per 01-01-2013\r\nBegindatum voor 1830            None
# 469                               Begindatum voor 1830            None
# 470                               Begindatum voor 1830            None
# 471   Opgeheven per 01-01-2019\r\nBegindatum voor 1830            None
# 472                            Ontstaan per 01-01-2010            None
# 473  Gemeentelijke herindeling per 01-01-1997\r\nBe...            None
# 474  Gemeentelijke herindeling per 01-01-2005\r\nBe...            None
# 475                            Ontstaan per 01-01-2001            None
# 476  Gemeentelijke herindeling per 01-01-2003\r\nBe...            None
# 477                               Begindatum voor 1830            None
# 478  In het verleden behoorden bepaalde delen van h...            None
# 479  RE = Regionale eenheid\r\n\r\nDe indeling in r...            None
# 480  RE = Regionale eenheid\r\n\r\nDe indeling in r...            None
# 481  RE = Regionale eenheid\r\n\r\nDe indeling in r...            None
# 482  RE = Regionale eenheid\r\n\r\nDe indeling in r...            None
# 483  RE = Regionale eenheid\r\n\r\nDe indeling in r...            None
# 484  RE = Regionale eenheid\r\n\r\nDe indeling in r...            None
# 485  RE = Regionale eenheid\r\n\r\nDe indeling in r...            None
# 486  RE = Regionale eenheid\r\n\r\nDe indeling in r...            None
# 487  RE = Regionale eenheid\r\n\r\nDe indeling in r...            None
# 488  RE = Regionale eenheid\r\n\r\nDe indeling in r...            None
# 489  RE = Regionale eenheid\r\n\r\nDe indeling in r...            None

# %%
print(metadata['Description'][3])
# Out:
# Een ingeschreven (rechtbank)strafzaak is een bij het parket ingeschreven dossier met het proces-verbaal van aangifte ten aanzien van één verdachte. Als er meer verdachten in een proces-verbaal voorkomen wordt voor iedere verdachte een strafzaak ingeschreven.

# %%
# for 83223NED
data = pd.DataFrame(cbs.get_data('83223NED',
                                      select = ['Regiokenmerken', 'Perioden',
                                                'Misdrijven', 'IngeschrevenRechtbankstrafzaken_1']))

# %%
# for 83648NED
filters = ["SoortMisdrijf eq 'CRI1000'",
           "SoortMisdrijf eq 'CRI2000'",
           "SoortMisdrijf eq 'CRI3000'",
           "SoortMisdrijf eq 'CRI4000'",
           "SoortMisdrijf eq 'CRI5000'",
           "SoortMisdrijf eq 'CRI6000'",
           "SoortMisdrijf eq 'CRI7000'",
           "SoortMisdrijf eq 'CRI9000'"]

data = pd.DataFrame()
for x in filters:
    data = data.append(pd.DataFrame(cbs.get_data('83648NED',
                                          select = ['RegioS', 'Perioden',
                                                    'GeregistreerdeMisdrijvenPer1000Inw_3', 'SoortMisdrijf'],
                                         filters =  x)))

# %%
val = 'GeregistreerdeMisdrijvenPer1000Inw_3'
cat = 'SoortMisdrijf'
reg = 'RegioS'
year = 'Perioden'
data = split_column(data, val, cat, reg, year)

# %%
data.to_csv('Crime.csv')

# %% [markdown]
# ## Downloading Data Number of workers in industries

# %% [markdown]
# For number of total workers:
# currently in dataset: 83582NED - from 2010 to 2019
#
#
# addition 1: 70742ned - from 1993 to 2005
#
# addition 2: 81402ned - from 2008 to 2014,
#
# ACTUALLY, use this one: 84419NED
# - we now need work volume, not number of jobs

# %% [markdown]
# For number of workers in industry at beginning of timeframe: 70090ENG

# %% [markdown]
# ### Workers in industries

# %%
metadata = pd.DataFrame(cbs.get_meta('70090NED', 'RegioS'))
metadata
# Out:
#          Key                                Title  \
# 0   NL1                                 Nederland
# 1   ExTR                 Extra-territoriale regio
# 2   LD01                          Noord-Nederland
# 3   LD02                           Oost-Nederland
# 4   LD03                           West-Nederland
# 5   LD04                           Zuid-Nederland
# 6   PV20                           Groningen (pv)
# 7   PV21                           Friesland (pv)
# 8   PV22                             Drenthe (pv)
# 9   PV23                          Overijssel (pv)
# 10  PV24                           Flevoland (pv)
# 11  PV25                          Gelderland (pv)
# 12  PV26                             Utrecht (pv)
# 13  PV27                       Noord-Holland (pv)
# 14  PV28                        Zuid-Holland (pv)
# 15  PV29                             Zeeland (pv)
# 16  PV30                       Noord-Brabant (pv)
# 17  PV31                             Limburg (pv)
# 18  CR01                           Oost-Groningen
# 19  CR02                     Delfzijl en omgeving
# 20  CR03                         Overig Groningen
# 21  CR04                          Noord-Friesland
# 22  CR05                       Zuidwest-Friesland
# 23  CR06                       Zuidoost-Friesland
# 24  CR07                            Noord-Drenthe
# 25  CR08                         Zuidoost-Drenthe
# 26  CR09                         Zuidwest-Drenthe
# 27  CR10                         Noord-Overijssel
# 28  CR11                      Zuidwest-Overijssel
# 29  CR12                                   Twente
# 30  CR13                                   Veluwe
# 31  CR14                               Achterhoek
# 32  CR15                          Arnhem/Nijmegen
# 33  CR16                      Zuidwest-Gelderland
# 34  CR17                                  Utrecht
# 35  CR18                    Kop van Noord-Holland
# 36  CR19                      Alkmaar en omgeving
# 37  CR20                                   IJmond
# 38  CR21                     Agglomeratie Haarlem
# 39  CR22                               Zaanstreek
# 40  CR23                          Groot-Amsterdam
# 41  CR24                  Het Gooi en Vechtstreek
# 42  CR25      Agglomeratie Leiden en Bollenstreek
# 43  CR26               Agglomeratie 's-Gravenhage
# 44  CR27                        Delft en Westland
# 45  CR28                        Oost-Zuid-Holland
# 46  CR29                           Groot-Rijnmond
# 47  CR30                    Zuidoost-Zuid-Holland
# 48  CR31                      Zeeuwsch-Vlaanderen
# 49  CR32                           Overig Zeeland
# 50  CR33                       West-Noord-Brabant
# 51  CR34                     Midden-Noord-Brabant
# 52  CR35                  Noordoost-Noord-Brabant
# 53  CR36                   Zuidoost-Noord-Brabant
# 54  CR37                            Noord-Limburg
# 55  CR38                           Midden-Limburg
# 56  CR39                             Zuid-Limburg
# 57  CR40                                Flevoland
# 58  R23A                                Amsterdam
# 59  R23G                   Overig Groot-Amsterdam
# 60  R29A                                 Rijnmond
# 61  R29B                    Overig Groot-Rijnmond
# 62  R35A             Stadsgewest 's-Hertogenbosch
# 63  R35B           Overig Noordoost-Noord-Brabant
#
#                                           Description CategoryGroupID
# 0                                                None            None
# 1   Omvat de territoriale wateren, het Nederlandse...            None
# 2   Omvat de provincies Groningen, Friesland en Dr...            None
# 3   Omvat de provincies Gelderland, Overijssel en ...            None
# 4   Omvat de provincies Noord-Holland, Zuid-Hollan...            None
# 5       Omvat de provincies Noord-Brabant en Limburg.            None
# 6   Omvat de volgende COROP-gebieden Oost-Groninge...            None
# 7   Omvat de volgende COROP-gebieden Noord-Friesla...            None
# 8   Omvat de volgende COROP-gebieden Noord-Drenthe...            None
# 9   Omvat de volgende COROP-gebieden Noord-Overijs...            None
# 10                    Betreft COROP-gebied Flevoland.            None
# 11  Omvat de volgende COROP-gebieden Veluwe, Achte...            None
# 12                      Betreft COROP-gebied Utrecht.            None
# 13  Omvat de volgende COROP-gebieden Kop van Noord...            None
# 14  Omvat de volgende COROP-gebieden Agglomeratie ...            None
# 15  Omvat de volgende COROP-gebieden Zeeuwsch-Vlaa...            None
# 16  Omvat de volgende COROP-gebieden West-Noord-Br...            None
# 17  Omvat de volgende COROP-gebieden Noord-Limburg...            None
# 18  Valt onder de provincie Groningen.\r\nI.v.m. d...            None
# 19  Valt onder de provincie Groningen.\r\nI.v.m. d...            None
# 20  Valt onder de provincie Groningen.\r\nI.v.m. d...            None
# 21  Valt onder de provincie Friesland.\r\nI.v.m. d...            None
# 22  Valt onder de provincie Friesland.\r\nI.v.m. d...            None
# 23  Valt onder de provincie Friesland.\r\nI.v.m. d...            None
# 24  Valt onder de provincie Drenthe.\r\nI.v.m. de ...            None
# 25  Valt onder de provincie Drenthe.\r\nI.v.m. de ...            None
# 26  Valt onder de provincie Drenthe.\r\nI.v.m. de ...            None
# 27  Valt onder de provincie Overijssel.\r\nI.v.m. ...            None
# 28  Valt onder de provincie Overijssel.\r\nI.v.m. ...            None
# 29  Valt onder de provincie Overijssel.\r\nI.v.m. ...            None
# 30  Valt onder de provincie Gelderland.\r\nI.v.m. ...            None
# 31  Valt onder de provincie Gelderland.\r\nI.v.m. ...            None
# 32                Valt onder de provincie Gelderland.            None
# 33  Valt onder de provincie Gelderland.\r\nI.v.m. ...            None
# 34                   Valt onder de provincie Utrecht.            None
# 35  Valt onder de provincie Noord-Holland.\r\nI.v....            None
# 36  Valt onder de provincie Noord-Holland.\r\nI.v....            None
# 37  Valt onder de provincie Noord-Holland.\r\nI.v....            None
# 38  Valt onder de provincie Noord-Holland\r\nI.v.m...            None
# 39  Valt onder de provincie Noord-Holland.\r\nI.v....            None
# 40             Valt onder de provincie Noord-Holland.            None
# 41  Valt onder de provincie Noord-Holland.\r\nI.v....            None
# 42  Valt onder de provincie Zuid-Holland.\r\nI.v.m...            None
# 43  Valt onder de provincie Zuid-Holland.\r\nI.v.m...            None
# 44  Valt onder de provincie Zuid-Holland.\r\nI.v.m...            None
# 45  Valt onder de provincie Zuid-Holland.\r\nI.v.m...            None
# 46              Valt onder de provincie Zuid-Holland.            None
# 47  Valt onder de provincie Zuid-Holland.\r\nI.v.m...            None
# 48  Valt onder de provincie Zeeland.\r\nI.v.m. de ...            None
# 49  Valt onder de provincie Zeeland.\r\nI.v.m. de ...            None
# 50  Valt onder de provincie Noord-Brabant.\r\nI.v....            None
# 51  Valt onder de provincie Noord-Brabant.\r\nI.v....            None
# 52             Valt onder de provincie Noord-Brabant.            None
# 53  Valt onder de provincie Noord-Brabant.\r\nI.v....            None
# 54  Valt onder de provincie Limburg.\r\nI.v.m. de ...            None
# 55  Valt onder de provincie Limburg.\r\nI.v.m. de ...            None
# 56  Valt onder de provincie Limburg.\r\nI.v.m. de ...            None
# 57                 Valt onder de provincie Flevoland.            None
# 58  Valt onder COROP-gebied Groot-Amsterdam.\r\nI....            None
# 59  Valt onder COROP-gebied Groot-Amsterdam.\r\nI....            None
# 60  Valt onder COROP-gebied Groot-Rijnmond.\r\nI.v...            None
# 61  Valt onder COROP-gebied Groot-Rijnmond.\r\nI.v...            None
# 62  Valt onder COROP-gebied Noordoost-Noord-Braban...            None
# 63  Valt onder COROP-gebied Noordoost-Noord-Braban...            None

# %%
print(metadata['Description'][15])
# Out:
# Omvat de volgende COROP-gebieden Zeeuwsch-Vlaanderen en Overig Zeeland.
# I.v.m. de geheimhouding is samengenomen:
# SBI 28 Metaalproductenindustrie en SBI DK Machine-industrie bij
# SBI 27 Basismetaalindustrie.

# %%
# Only get data for provinces and corop regions
reglist = [f"RegioS eq '{x}'" for x in metadata.Key.tolist() if x.startswith('PV') or x.startswith('CR') or x.startswith('NL')]

data = pd.DataFrame()
for y in reglist:
    data = data.append(pd.DataFrame(cbs.get_data('70090NED',
                                          select = ['RegioS', 'Perioden','SBI93','Arbeidsvolume_2'],
                                         filters =  y)))
    
# Transform string value in Perioden into int
data['Perioden'] = data['Perioden'].replace(to_replace = ' \w+', value='', regex=True).astype(int)

# Only data from Industry and all industries + only 2008 and 2009
data = data[data['SBI93'].str.contains(r'(^2)|(^D[A-Z])|(Overige)|(Totaal bedrijfsactiviteiten)')]

# Change (pv) to (PV)
data.RegioS = data.RegioS.str.replace('\(pv\)', '(PV)', regex=True)

# Change w/o (PV) to (CR)
data.loc[~data.RegioS.str.startswith('Nederland') & ~data.RegioS.str.endswith('(PV)'),['RegioS']] = data.loc[data.RegioS.str.endswith('(PV)') & ~data.RegioS.str.endswith('(PV)')]['RegioS'] + ' (CR)'
# Out:
# /home/hennes/.local/lib/python3.8/site-packages/pandas/core/strings/accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
# Turn dataset wide

val = 'Arbeidsvolume_2'
cat = 'SBI93'
reg = 'RegioS'
year = 'Perioden'
data = split_column(data, val, cat, reg, year)

# %%
data = data.rename(columns={'DA Voedings- en genotmiddelen_Arbeidsvolume_2':'labour_food, beverages, tobacco',
                           'DB+DC Textiel en leder_Arbeidsvolume_2':'labour_textile, clothes, leather',
                           '21 Papier en karton_Arbeidsvolume_2':'labour_paper, carton',
                           '22 Uitgeverijen en drukkerijen_Arbeidsvolume_2':'labour_printing, recorded media',
                           'DF Aardolie- en steenkool industrie_Arbeidsvolume_2':'labour_coke_and_refined_petrolium',
                           'DG+DH Chemische, rubber en kunststof ind_Arbeidsvolume_2':'labour_chemicals, chemical products, non-metallic products',
                           '27 Basismetaalindustrie_Arbeidsvolume_2':'labour_basic_metals',
                           '28+DK Metaalproducten en machine ind._Arbeidsvolume_2':'labour_metal_products,_machinery_and_equipment',
                           'DL Elektrotechnische industrie_Arbeidsvolume_2':'labour_electronic_products',
                           'DM Transportmiddelen industrie_Arbeidsvolume_2':'labour_transport_vehicles',
                           'Overige industrie_Arbeidsvolume_2':'labour_other industrial products',
                           'Totaal bedrijfsactiviteiten_Arbeidsvolume_2':'labour_all_industries'})

# %% [markdown]
# labour_food, beverages, tobacco --> 'import_food_products', 'import_beverages', 'import_tobacco_products',
# labour_textile, clothes, leather --> 'import_textiles', 'import_wearing_apparel', 'import_leather_and_leather-related_products'
#
# labour_paper, carton --> import_paper_and_related_products
# labour_printing, recorded media --> import_printing_and_recorded_media
# labour_coke_and_refined_petrolium --> import_coke_and_refined_petrolium
# labour_chemicals, chemical products, non-metallic products --> 'import_chemicals_and_chemical_products', import_basic_pharmaceutical_products_and_preparations',  'import_rubber_and_plastic_products',
#
# labour_basic_metals --> import_basic_metals
# labour_metal_products,_machinery_and_equipment --> 'import_fabricated_metal_products',  'import_machinery_and_equipment'
#
# labour_electronic_products -->  'import_computer_electronic_and_optical_products', 'import_electrical_equipment',
# labour_transport_vehicles -->  'import_motor_vehicles_trailers_and_semi-trailers','import_other_transport_equipment'
#
# labour_other industrial products --> import_wood_and_wood_products, 'import_other_non-metallic_products',  'import_furniture', 'import_other'

# %%
data.to_csv('Workers.csv')

# %% [markdown]
# ## Downloading Data for change in Chinese Imports

# %%
metadata = pd.DataFrame(cbs.get_meta('83028NED', 'SITC'))
metadata
# Out:
#         Key                                     Title  \
# 0   T001082                           Totaal goederen
# 1   A018524               0 Voeding en levende dieren
# 2   A018528                        1 Dranken en tabak
# 3   A018540  2 Grondstoffen, niet eetbaar, behalve...
# 4   A018591  3 Minerale brandstoffen, smeermiddele...
# 5   A018612  4 Dierlijke en plantaardige oliën en ...
# 6   A018629                     5 Chemische producten
# 7   A018678  6 Fabricaten hoofdzakelijk gerangschi...
# 8   A018743            7 Machines en vervoermaterieel
# 9   A018809          8 Diverse gefabriceerde goederen
# 10  A018851     9 Niet afzonderlijk genoemde goederen
#
#                                           Description CategoryGroupID
# 0                                                                None
# 1                                                                None
# 2                                                                None
# 3   2 Grondstoffen, niet eetbaar, behalve brandsto...            None
# 4   3 Minerale brandstoffen, smeermiddelen en derg...            None
# 5         4 Dierlijke en plantaardige oliën en vetten            None
# 6                                                                None
# 7   6 Fabricaten hoofdzakelijk gerangschikt volgen...            None
# 8                                                                None
# 9                                                                None
# 10                                                               None

# %%
print(metadata['Description'][7])
# Out:
# 6 Fabricaten hoofdzakelijk gerangschikt volgens grondstoffen

# %%
data = pd.DataFrame(cbs.get_data('83028NED',
                                          select = ['SITC', 'Perioden','Invoerwaarde_1', 'LandenGroepen'],
                                          filters = "LandenGroepen eq 'L008575'"))

data = data[(data['Perioden'].str.match(r'(^\d{4}$)|(^\d{4} $)'))]
data['Perioden'] = data['Perioden'].astype(int)

# %%
for x in data[f'SITC'].unique():
            data[f'{x}_Invoerwaarde_1'] = np.where(data[f'SITC'] == x, data[f'Invoerwaarde_1'], None)
data = data.drop([f'Invoerwaarde_1'], axis=1)
data['RegioS'] = 'Nederland'
data = data.groupby(['RegioS', 'Perioden']).agg(max).drop([f'SITC'], axis=1)

# %%
data.to_csv('Imports.csv')

# %% [markdown]
# ## Importing Election data

# %%
for file in glob('Elections/*'):
    data = pd.read_csv(file, sep=';')
    data.iloc[:, 10:] = data.iloc[:, 10:].div(data.GeldigeStemmen, axis=0) # transform absolute votes into relative share
    data['RegioS'] = data['RegioNaam']
    year = re.search(r'\d{4}',file).group(0)
    data['Perioden'] = year
    data['turnout'] = data.Opkomst/data.Kiesgerechtigden
    data.set_index(['RegioS', 'Perioden'], inplace=True)
    data = data.iloc[:, 10:]
    results = data.iloc[:, :-3]
    results = results[results.columns[(results>0.05).any()]]
    results['turnout'] = data['turnout']
    results.to_csv(f'election_{year}.csv')

# %%
data = pd.read_csv('election_1989.csv')
if 'Democraten 66 (D66)' in data.columns:
    data = data.rename(columns={'Democraten 66 (D66)':'D66'})
if 'Partij van de Arbeid (P.v.d.A.)' in data.columns:
    data = data.rename(columns={'Partij van de Arbeid (P.v.d.A.)':'PvdA'})
if 'Staatkundig Gereformeerde Partij (SGP)' in data.columns:
    data = data.rename(columns={'Staatkundig Gereformeerde Partij (SGP)':'SGP'})
if 'GROENLINKS' in data.columns:
    data = data.rename(columns={'GROENLINKS':'GL'})
for file in glob('*'):
    if (file.startswith('election')) and (file != 'election_1989.csv'):
        df = pd.read_csv(file)
        if 'Democraten 66 (D66)' in df.columns:
            df = df.rename(columns={'Democraten 66 (D66)':'D66'})
        if 'Partij van de Arbeid (P.v.d.A.)' in df.columns:
            df = df.rename(columns={'Partij van de Arbeid (P.v.d.A.)':'PvdA'})
        if 'Staatkundig Gereformeerde Partij (SGP)' in df.columns:
            df = df.rename(columns={'Staatkundig Gereformeerde Partij (SGP)':'SGP'})
        if 'GROENLINKS' in df.columns:
            df = df.rename(columns={'GROENLINKS':'GL'})
        data = data.merge(df, how='outer')

# %%
data = data.sort_values(by=['RegioS', 'Perioden']).set_index(['RegioS', 'Perioden'])

# %%
data.to_csv('elections.csv')
for file in glob('*'):
    if (file.startswith('election_')):
        os.remove(file)

# %% [markdown]
# ## Getting Gemeentelijke Indeeling

# %% [markdown]
# ### NUTS3

# %%
# I will do it instead with the Table List

# %%
import pprint

# %%
# Get dictionary with year dataset identifiers and matching year number

tables = [x for x in cbs.get_table_list() if x['Title'].startswith('Gebieden in Nederland')]
table_dict = dict(zip([re.search(r'\d{4}' ,x['Period']).group() for x in tables], [x['Identifier'] for x in tables]))

# %%
# Create dict withformat: dataset code: [year, variable name]
dict_combis = {}
for x, y in table_dict.items():
    metadata = pd.DataFrame(cbs.get_meta(y, 'DataProperties'))
    key = metadata[metadata['Description'].str.contains(r'Namen van de (COROP|Corop)-gebieden',
                                                        na=False)].Key.tolist()[0]
    dict_combis.update({x:[y, key]})
# Out:
# /home/hennes/.local/lib/python3.8/site-packages/pandas/core/strings/accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
# download gemeente NUTS3 translations for every year

df = []
for x, y in dict_combis.items():
    if int(x) > 2002:
        data = pd.DataFrame(cbs.get_data(y[0], select = [y[1], 'RegioS']))
        data['Perioden'] = x
        data.rename(columns={f'{y[1]}': 'nuts3'}, inplace=True)
        df.append(data)
    else:
        data = pd.DataFrame(cbs.get_data(y[0], select = [y[1], 'Gemeenten']))
        data['Perioden'] = x
        data.rename(columns={'Gemeenten':'RegioS', f'{y[1]}': 'nuts3'}, inplace=True)
        df.append(data)
df = pd.concat(df)
df.to_csv('nuts3.csv')

# %% [markdown]
# ### NUTS2

# %%
import pprint

# %%
# Get dictionary with year dataset identifiers and matching year number

tables = [x for x in cbs.get_table_list() if x['Title'].startswith('Gebieden in Nederland')]
table_dict = dict(zip([re.search(r'\d{4}' ,x['Period']).group() for x in tables], [x['Identifier'] for x in tables]))

# %%
# Create dict withformat: dataset code: [year, variable name]
dict_combis = {}
for x, y in table_dict.items():
    metadata = pd.DataFrame(cbs.get_meta(y, 'DataProperties'))
    key = metadata[metadata['Description'].str.contains(r'Namen van de provincies',
                                                        na=False)].Key.tolist()[0]
    dict_combis.update({x:[y, key]})

# %%
# download gemeente NUTS2 translations for every year

df = []
for x, y in dict_combis.items():
    if int(x) > 2002:
        data = pd.DataFrame(cbs.get_data(y[0], select = [y[1], 'RegioS']))
        data['Perioden'] = x
        data.rename(columns={f'{y[1]}': 'nuts2'}, inplace=True)
        df.append(data)
    else:
        data = pd.DataFrame(cbs.get_data(y[0], select = [y[1], 'Gemeenten']))
        data['Perioden'] = x
        data.rename(columns={'Gemeenten':'RegioS', f'{y[1]}': 'nuts2'}, inplace=True)
        df.append(data)
df = pd.concat(df)
df.to_csv('nuts2.csv')
